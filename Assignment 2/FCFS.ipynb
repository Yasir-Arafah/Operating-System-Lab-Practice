# %%
at = []
bt = []
pro = []

n = int(input("Enter the number of process: "))

for i in range(1, n+1):

  pro.append("P%d" %i)
  a = int(input("P%d arrival time: " %i))
  at.append(a)
  b = int(input("P%d burst time: " %i))
  bt.append(b)


import pandas as pd
chart = {"Process No" : pro,
         "Arrival Time" : at,
         "Burst Time" : bt}
df = pd.DataFrame(chart)
print()
print(df)


df = df.sort_values(by='Arrival Time')
print()
print("Sorted Data: ")
print()
print(df)


new_pro = list(df["Process No"])
new_at = list(df["Arrival Time"])
new_bt = list(df["Burst Time"])

print()
print("Process No: ")
print(new_pro)
print("Arrival Time: ")
print(new_at)
print("Burst Time: ")
print(new_bt)


ct = []
calc = 0

for i in range(n):
  if i == 0:
    if new_at[i] == 0:
      calc = calc + new_bt[i]
      ct.append(calc)
    elif new_at[i] != 0:
      calc = calc + new_at[i] + new_bt[i]
      ct.append(calc)
  elif i > 0:
    if new_at[i] < calc:
      calc = calc + new_bt[i]
      ct.append(calc)
    else:
      d = new_at[i] - calc
      calc = calc + new_bt[i] + d
      ct.append(calc)

print()
print("Process No: ")
print(new_pro)
print("Completion time: ")
print(ct)


tat = []
wt =[]

for i in range(n):
  tat.append(ct[i] - new_at[i])
  wt.append(tat[i] - new_bt[i])

print()
print("Turn around time: ")
print(tat)
print()
print("Waiting time: ")
print(wt)


chart = {"Process No" : new_pro,
         "Arrival Time" : new_at,
         "Burst Time" : new_bt,
         "Completion Time" : ct,
         "Turn Around Time" : tat,
         "Waiting Time" : wt}
df2 = pd.DataFrame(chart)
df2 = df2.sort_values(by=['Process No'])



print()
print("Average Waiting Time: ", df2["Waiting Time"].mean())
print()
print("Average Turn Around Time: ", df2["Turn Around Time"].mean())

print()
df2
# Out:
# Enter the number of process: 3
# P1 arrival time: 4
# P1 burst time: 5
# P2 arrival time: 0
# P2 burst time: 7
# P3 arrival time: 2
# P3 burst time: 9
#
#   Process No  Arrival Time  Burst Time
# 0         P1             4           5
# 1         P2             0           7
# 2         P3             2           9
#
# Sorted Data:
#
#   Process No  Arrival Time  Burst Time
# 1         P2             0           7
# 2         P3             2           9
# 0         P1             4           5
#
# Process No:
# ['P2', 'P3', 'P1']
# Arrival Time:
# [0, 2, 4]
# Burst Time:
# [7, 9, 5]
#
# Process No:
# ['P2', 'P3', 'P1']
# Completion time:
# [7, 16, 21]
#
# Turn around time:
# [7, 14, 17]
#
# Waiting time:
# [0, 5, 12]
#
# Average Waiting Time:  5.666666666666667
#
# Average Turn Around Time:  12.666666666666666
#   Process No  Arrival Time  Burst Time  Completion Time  Turn Around Time  \
# 2         P1             4           5               21                17
# 0         P2             0           7                7                 7
# 1         P3             2           9               16                14
#
#    Waiting Time
# 2            12
# 0             0
# 1             5
